# %%
import pandas as pd
import os

# %%
os.chdir('..')

# %%
base_folder = 'data'

# %%
[f.path for f in os.scandir(base_folder) if f.is_dir()]
# Out:
# ['data/Cities',
#  'data/Subscription source',
#  'data/Operating system',
#  'data/New and returning viewers',
#  'data/Viewer age',
#  'data/Geography',
#  'data/Subtitles and CC',
#  'data/Subscription status',
#  'data/Content type',
#  'data/Viewer gender',
#  'data/Viewership by Date',
#  'data/Device type',
#  'data/Sharing service',
#  'data/Traffic source']

# %%
# Get a list of all subfolders in the base folder
subfolders = [f.path for f in os.scandir(base_folder) if f.is_dir()]

# %%
all_merged_datas = []  # List to store merged dataframes

# %%
# Iterate through each subfolder
for subfolder in subfolders:
    try:
        # Construct the file paths for each CSV within the subfolder
        totals_path = os.path.join(subfolder, 'Totals.csv')
        print(totals_path)
        chart_path = os.path.join(subfolder, 'Chart data.csv')
        print(chart_path)
        table_path = os.path.join(subfolder, 'Table data.csv')
        print(table_path)

        # Read CSV files with error handling
        try:
            totals_data = pd.read_csv(totals_path)
        except FileNotFoundError:
            totals_data = pd.DataFrame({'Date': [], 'Views': []})

        try:
            chart_data = pd.read_csv(chart_path)
        except FileNotFoundError:
            chart_data = pd.DataFrame({'Date': [], 'Cities': [], 'City name': [], 'Views': []})

        try:
            table_data = pd.read_csv(table_path)
        except FileNotFoundError:
            table_data = pd.DataFrame({'Cities': [], 'City name': [], 'Geography': [], 'Views': [],
                                       'Watch time (hours)': [], 'Average view duration': []})

        # Find common columns dynamically
        common_columns = set(chart_data.columns) & set(table_data.columns)
        print(f"common columns between chart_data and table_data: {common_columns}")

        # Check if there are common columns
        if common_columns:
            # Merge "chart_data" with "table_data" based on the common columns 
            merged_data = pd.merge(chart_data, table_data, on=list(common_columns), how='left')

            # Merge the result with the "Totals" data based on the "Date" column
            final_data = pd.merge(merged_data, totals_data, on='Date', how='left')
        
            # Append the merged dataframe to the list
            all_merged_datas.append(final_data)

            # Display the final merged data for the current subfolder
            print(f'\nMerged Data for {subfolder}:')
            print(final_data)

            # Save the merged data to a new CSV file within each subfolder
            output_path = os.path.join(subfolder, 'merged_data.csv')
            final_data.to_csv(output_path, index=False)
        else:
            print(f"Skipping {subfolder}: No common columns found between chart_data and table_data.")

    except Exception as e:
        print(f"Error processing {subfolder}: {str(e)}")

print("\nProcessing complete.")
# Out:
# data/Cities/Totals.csv
# data/Cities/Chart data.csv
# data/Cities/Table data.csv
# common columns between chart_data and table_data: {'Views', 'Cities', 'City name'}
#
# Merged Data for data/Cities:
#             Date                                 Cities    City name  Views_x  \
# 0     2020-06-28  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa        0
# 1     2020-06-29  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa        0
# 2     2020-06-30  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa        0
# 3     2020-07-01  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa        0
# 4     2020-07-02  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa        0
# ...          ...                                    ...          ...      ...
# 6390  2023-12-24  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester        0
# 6391  2023-12-25  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester        0
# 6392  2023-12-26  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester        0
# 6393  2023-12-27  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester        0
# 6394  2023-12-28  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester        0
#
#      Geography Geography.1  Watch time (hours) Average view duration  Views_y
# 0          NaN         NaN                 NaN                   NaN        1
# 1          NaN         NaN                 NaN                   NaN       72
# 2          NaN         NaN                 NaN                   NaN       76
# 3          NaN         NaN                 NaN                   NaN       70
# 4          NaN         NaN                 NaN                   NaN       57
# ...        ...         ...                 ...                   ...      ...
# 6390       NaN         NaN                 NaN                   NaN       36
# 6391       NaN         NaN                 NaN                   NaN       24
# 6392       NaN         NaN                 NaN                   NaN       57
# 6393       NaN         NaN                 NaN                   NaN        8
# 6394       NaN         NaN                 NaN                   NaN       25
#
# [6395 rows x 9 columns]
# data/Subscription source/Totals.csv
# data/Subscription source/Chart data.csv
# data/Subscription source/Table data.csv
# common columns between chart_data and table_data: {'Subscription source', 'Subscribers'}
#
# Merged Data for data/Subscription source:
#              Date Subscription source  Subscribers_x  Subscribers gained  \
# 0      2020-06-28               Other              0                 NaN
# 1      2020-06-29               Other              0                 NaN
# 2      2020-06-30               Other              0                 NaN
# 3      2020-07-01               Other              0                 NaN
# 4      2020-07-02               Other              1                 NaN
# ...           ...                 ...            ...                 ...
# 10227  2023-12-24      YouTube search              0                 NaN
# 10228  2023-12-25      YouTube search              0                 NaN
# 10229  2023-12-26      YouTube search              0                 NaN
# 10230  2023-12-27      YouTube search              0                 NaN
# 10231  2023-12-28      YouTube search              0                 NaN
#
#        Subscribers lost  Subscribers_y
# 0                   NaN              1
# 1                   NaN             13
# 2                   NaN              4
# 3                   NaN              2
# 4                   NaN              2
# ...                 ...            ...
# 10227               NaN              0
# 10228               NaN              1
# 10229               NaN              0
# 10230               NaN              0
# 10231               NaN              0
#
# [10232 rows x 6 columns]
# data/Operating system/Totals.csv
# data/Operating system/Chart data.csv
# data/Operating system/Table data.csv
# common columns between chart_data and table_data: {'Operating system', 'Views'}
#
# Merged Data for data/Operating system:
#              Date Operating system  Views_x  Watch time (hours)  \
# 0      2020-06-28          Unknown        0                 0.0
# 1      2020-06-29          Unknown        0                 0.0
# 2      2020-06-30          Unknown        0                 0.0
# 3      2020-07-01          Unknown        0                 0.0
# 4      2020-07-02          Unknown        0                 0.0
# ...           ...              ...      ...                 ...
# 20459  2023-12-24        Chrome OS        0                 NaN
# 20460  2023-12-25        Chrome OS        0                 NaN
# 20461  2023-12-26        Chrome OS        0                 NaN
# 20462  2023-12-27        Chrome OS        0                 NaN
# 20463  2023-12-28        Chrome OS        0                 NaN
#
#       Average view duration  Views_y
# 0                       NaN        1
# 1                       NaN       72
# 2                       NaN       76
# 3                       NaN       70
# 4                       NaN       57
# ...                     ...      ...
# 20459                   NaN       36
# 20460                   NaN       24
# 20461                   NaN       57
# 20462                   NaN        8
# 20463                   NaN       25
#
# [20464 rows x 6 columns]
# data/New and returning viewers/Totals.csv
# data/New and returning viewers/Chart data.csv
# data/New and returning viewers/Table data.csv
# common columns between chart_data and table_data: {'Views', 'New and returning viewers'}
#
# Merged Data for data/New and returning viewers:
#             Date New and returning viewers  Views_x  Watch time (hours)  \
# 0     2020-06-28                   Unknown        1                 NaN
# 1     2020-06-29                   Unknown       72                 NaN
# 2     2020-06-30                   Unknown       76                 NaN
# 3     2020-07-01                   Unknown       70                 NaN
# 4     2020-07-02                   Unknown       57                 NaN
# ...          ...                       ...      ...                 ...
# 3832  2023-12-24         Returning viewers       33                 NaN
# 3833  2023-12-25         Returning viewers       24                 NaN
# 3834  2023-12-26         Returning viewers       41                 NaN
# 3835  2023-12-27         Returning viewers        3                 NaN
# 3836  2023-12-28         Returning viewers        0                 NaN
#
#      Average view duration  Views_y
# 0                      NaN        1
# 1                      NaN       72
# 2                      NaN       76
# 3                      NaN       70
# 4                      NaN       57
# ...                    ...      ...
# 3832                   NaN       36
# 3833                   NaN       24
# 3834                   NaN       57
# 3835                   NaN        8
# 3836                   NaN       25
#
# [3837 rows x 6 columns]
# data/Viewer age/Totals.csv
# data/Viewer age/Chart data.csv
# data/Viewer age/Table data.csv
# common columns between chart_data and table_data: set()
# Skipping data/Viewer age: No common columns found between chart_data and table_data.
# data/Geography/Totals.csv
# data/Geography/Chart data.csv
# data/Geography/Table data.csv
# common columns between chart_data and table_data: {'Views', 'Geography'}
#
# Merged Data for data/Geography:
#              Date Geography  Views_x  Watch time (hours)  \
# 0      2020-06-28        BJ        0                 NaN
# 1      2020-06-29        BJ        0                 NaN
# 2      2020-06-30        BJ        0                 NaN
# 3      2020-07-01        BJ        0                 NaN
# 4      2020-07-02        BJ        0                 NaN
# ...           ...       ...      ...                 ...
# 37086  2023-12-24        ZA        0                 NaN
# 37087  2023-12-25        ZA        0                 NaN
# 37088  2023-12-26        ZA        0                 NaN
# 37089  2023-12-27        ZA        0                 NaN
# 37090  2023-12-28        ZA        0                 NaN
#
#       Average view duration  Views_y
# 0                       NaN        1
# 1                       NaN       72
# 2                       NaN       76
# 3                       NaN       70
# 4                       NaN       57
# ...                     ...      ...
# 37086                   NaN       36
# 37087                   NaN       24
# 37088                   NaN       57
# 37089                   NaN        8
# 37090                   NaN       25
#
# [37091 rows x 6 columns]
# data/Subtitles and CC/Totals.csv
# data/Subtitles and CC/Chart data.csv
# data/Subtitles and CC/Table data.csv
# common columns between chart_data and table_data: {'Subtitles and CC', 'Views'}
#
# Merged Data for data/Subtitles and CC:
#              Date Subtitles and CC  Views_x  Watch time (hours)  \
# 0      2020-06-28              NaN        1                 NaN
# 1      2020-06-29              NaN       70                 NaN
# 2      2020-06-30              NaN       76                 NaN
# 3      2020-07-01              NaN       70                 NaN
# 4      2020-07-02              NaN       57                 NaN
# ...           ...              ...      ...                 ...
# 10227  2023-12-24              pt#        0                 NaN
# 10228  2023-12-25              pt#        0                 NaN
# 10229  2023-12-26              pt#        0                 NaN
# 10230  2023-12-27              pt#        0                 NaN
# 10231  2023-12-28              pt#        0                 NaN
#
#       Average view duration  Views_y
# 0                       NaN        1
# 1                       NaN       72
# 2                       NaN       76
# 3                       NaN       70
# 4                       NaN       57
# ...                     ...      ...
# 10227                   NaN       36
# 10228                   NaN       24
# 10229                   NaN       57
# 10230                   NaN        8
# 10231                   NaN       25
#
# [10232 rows x 6 columns]
# data/Subscription status/Totals.csv
# data/Subscription status/Chart data.csv
# data/Subscription status/Table data.csv
# common columns between chart_data and table_data: {'Views', 'Subscription status'}
#
# Merged Data for data/Subscription status:
#             Date Subscription status  Views_x  Watch time (hours)  \
# 0     2020-06-28          Subscribed        1                 NaN
# 1     2020-06-29          Subscribed       16                 NaN
# 2     2020-06-30          Subscribed       23                 NaN
# 3     2020-07-01          Subscribed       23                 NaN
# 4     2020-07-02          Subscribed       26                 NaN
# ...          ...                 ...      ...                 ...
# 2553  2023-12-24      Not subscribed        9                 NaN
# 2554  2023-12-25      Not subscribed       11                 NaN
# 2555  2023-12-26      Not subscribed       25                 NaN
# 2556  2023-12-27      Not subscribed        5                 NaN
# 2557  2023-12-28      Not subscribed        2                 NaN
#
#      Average view duration  Views_y
# 0                      NaN        1
# 1                      NaN       72
# 2                      NaN       76
# 3                      NaN       70
# 4                      NaN       57
# ...                    ...      ...
# 2553                   NaN       36
# 2554                   NaN       24
# 2555                   NaN       57
# 2556                   NaN        8
# 2557                   NaN       25
#
# [2558 rows x 6 columns]
# data/Content type/Totals.csv
# data/Content type/Chart data.csv
# data/Content type/Table data.csv
# common columns between chart_data and table_data: {'Content type', 'Views'}
#
# Merged Data for data/Content type:
#             Date Content type  Views_x  Watch time (hours)  \
# 0     2020-06-28        Other        0                 NaN
# 1     2020-06-29        Other        0                 NaN
# 2     2020-06-30        Other        0                 NaN
# 3     2020-07-01        Other        0                 NaN
# 4     2020-07-02        Other        0                 NaN
# ...          ...          ...      ...                 ...
# 2553  2023-12-24       Videos       36                 NaN
# 2554  2023-12-25       Videos       33                 NaN
# 2555  2023-12-26       Videos       57                 NaN
# 2556  2023-12-27       Videos        8                 NaN
# 2557  2023-12-28       Videos       25                 NaN
#
#      Average view duration  Views_y
# 0                      NaN        1
# 1                      NaN       72
# 2                      NaN       76
# 3                      NaN       70
# 4                      NaN       57
# ...                    ...      ...
# 2553                   NaN       36
# 2554                   NaN       24
# 2555                   NaN       57
# 2556                   NaN        8
# 2557                   NaN       25
#
# [2558 rows x 6 columns]
# data/Viewer gender/Totals.csv
# data/Viewer gender/Chart data.csv
# data/Viewer gender/Table data.csv
# common columns between chart_data and table_data: set()
# Skipping data/Viewer gender: No common columns found between chart_data and table_data.
# data/Viewership by Date/Totals.csv
# data/Viewership by Date/Chart data.csv
# data/Viewership by Date/Table data.csv
# common columns between chart_data and table_data: {'Views', 'Date'}
#
# Merged Data for data/Viewership by Date:
# Empty DataFrame
# Columns: [Cities, City name, Views_x, Watch time (hours), Average view duration, Date, Views_y]
# Index: []
# data/Device type/Totals.csv
# data/Device type/Chart data.csv
# data/Device type/Table data.csv
# common columns between chart_data and table_data: {'Views', 'Device type'}
#
# Merged Data for data/Device type:
#             Date Device type  Views_x  Watch time (hours)  \
# 0     2020-06-28    Computer        1                 NaN
# 1     2020-06-29    Computer       49                 NaN
# 2     2020-06-30    Computer       62                 NaN
# 3     2020-07-01    Computer       46                 NaN
# 4     2020-07-02    Computer       29                 NaN
# ...          ...         ...      ...                 ...
# 5111  2023-12-24      Tablet        0                 NaN
# 5112  2023-12-25      Tablet        0                 NaN
# 5113  2023-12-26      Tablet        0                 NaN
# 5114  2023-12-27      Tablet        0                 NaN
# 5115  2023-12-28      Tablet        0                 NaN
#
#      Average view duration  Views_y
# 0                      NaN        1
# 1                      NaN       72
# 2                      NaN       76
# 3                      NaN       70
# 4                      NaN       57
# ...                    ...      ...
# 5111                   NaN       36
# 5112                   NaN       24
# 5113                   NaN       57
# 5114                   NaN        8
# 5115                   NaN       25
#
# [5116 rows x 6 columns]
# data/Sharing service/Totals.csv
# data/Sharing service/Chart data.csv
# data/Sharing service/Table data.csv
# common columns between chart_data and table_data: {'Shares', 'Sharing service'}
#
# Merged Data for data/Sharing service:
#              Date             Sharing service  Shares_x  Shares_y
# 0      2020-06-28                    Facebook         0         0
# 1      2020-06-29                    Facebook         0         1
# 2      2020-06-30                    Facebook         0         0
# 3      2020-07-01                    Facebook         0         0
# 4      2020-07-02                    Facebook         0         0
# ...           ...                         ...       ...       ...
# 11506  2023-12-24  Share to WhatsApp Business         0         0
# 11507  2023-12-25  Share to WhatsApp Business         0         0
# 11508  2023-12-26  Share to WhatsApp Business         0         0
# 11509  2023-12-27  Share to WhatsApp Business         0         0
# 11510  2023-12-28  Share to WhatsApp Business         0         0
#
# [11511 rows x 4 columns]
# data/Traffic source/Totals.csv
# data/Traffic source/Chart data.csv
# data/Traffic source/Table data.csv
# common columns between chart_data and table_data: {'Traffic source', 'Views'}
#
# Merged Data for data/Traffic source:
#              Date     Traffic source  Views_x  Watch time (hours)  \
# 0      2020-06-28  Direct or unknown        0                 NaN
# 1      2020-06-29  Direct or unknown        6                 NaN
# 2      2020-06-30  Direct or unknown        2                 NaN
# 3      2020-07-01  Direct or unknown        3                 NaN
# 4      2020-07-02  Direct or unknown        0                 NaN
# ...           ...                ...      ...                 ...
# 11506  2023-12-24      Notifications        1                 NaN
# 11507  2023-12-25      Notifications        2                 NaN
# 11508  2023-12-26      Notifications        4                 NaN
# 11509  2023-12-27      Notifications        0                 NaN
# 11510  2023-12-28      Notifications        2                 NaN
#
#       Average view duration  Impressions  Impressions click-through rate (%)  \
# 0                       NaN          NaN                                 NaN
# 1                       NaN          NaN                                 NaN
# 2                       NaN          NaN                                 NaN
# 3                       NaN          NaN                                 NaN
# 4                       NaN          NaN                                 NaN
# ...                     ...          ...                                 ...
# 11506                   NaN          NaN                                 NaN
# 11507                   NaN          NaN                                 NaN
# 11508                   NaN          NaN                                 NaN
# 11509                   NaN          NaN                                 NaN
# 11510                   NaN          NaN                                 NaN
#
#        Views_y
# 0            1
# 1           72
# 2           76
# 3           70
# 4           57
# ...        ...
# 11506       36
# 11507       24
# 11508       57
# 11509        8
# 11510       25
#
# [11511 rows x 8 columns]
#
# Processing complete.

# %%
# Concatenate all merged datas into a single dataframe
if all_merged_datas:
    all_merged_data = pd.concat(all_merged_datas, ignore_index=True)

    # Display the final concatenated dataframe
    print("\nConcatenated Data:")
    print(all_merged_data)

    # Save the concatenated dataframe to a new CSV file
    all_output_path = os.path.join("data", 'all_merged_data.csv')
    all_merged_data.to_csv(all_output_path, index=False)
else:
    print("No common columns found in any subfolder.")
# Out:
# Concatenated Data:
#               Date                                 Cities    City name  \
# 0       2020-06-28  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 1       2020-06-29  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 2       2020-06-30  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 3       2020-07-01  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 4       2020-07-02  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# ...            ...                                    ...          ...
# 121500  2023-12-24                                    NaN          NaN
# 121501  2023-12-25                                    NaN          NaN
# 121502  2023-12-26                                    NaN          NaN
# 121503  2023-12-27                                    NaN          NaN
# 121504  2023-12-28                                    NaN          NaN
#
#         Views_x Geography Geography.1  Watch time (hours)  \
# 0           0.0       NaN         NaN                 NaN
# 1           0.0       NaN         NaN                 NaN
# 2           0.0       NaN         NaN                 NaN
# 3           0.0       NaN         NaN                 NaN
# 4           0.0       NaN         NaN                 NaN
# ...         ...       ...         ...                 ...
# 121500      1.0       NaN         NaN                 NaN
# 121501      2.0       NaN         NaN                 NaN
# 121502      4.0       NaN         NaN                 NaN
# 121503      0.0       NaN         NaN                 NaN
# 121504      2.0       NaN         NaN                 NaN
#
#        Average view duration  Views_y Subscription source  ...  \
# 0                        NaN      1.0                 NaN  ...
# 1                        NaN     72.0                 NaN  ...
# 2                        NaN     76.0                 NaN  ...
# 3                        NaN     70.0                 NaN  ...
# 4                        NaN     57.0                 NaN  ...
# ...                      ...      ...                 ...  ...
# 121500                   NaN     36.0                 NaN  ...
# 121501                   NaN     24.0                 NaN  ...
# 121502                   NaN     57.0                 NaN  ...
# 121503                   NaN      8.0                 NaN  ...
# 121504                   NaN     25.0                 NaN  ...
#
#         Subtitles and CC  Subscription status  Content type  Device type  \
# 0                    NaN                  NaN           NaN          NaN
# 1                    NaN                  NaN           NaN          NaN
# 2                    NaN                  NaN           NaN          NaN
# 3                    NaN                  NaN           NaN          NaN
# 4                    NaN                  NaN           NaN          NaN
# ...                  ...                  ...           ...          ...
# 121500               NaN                  NaN           NaN          NaN
# 121501               NaN                  NaN           NaN          NaN
# 121502               NaN                  NaN           NaN          NaN
# 121503               NaN                  NaN           NaN          NaN
# 121504               NaN                  NaN           NaN          NaN
#
#        Sharing service Shares_x Shares_y Traffic source Impressions  \
# 0                  NaN      NaN      NaN            NaN         NaN
# 1                  NaN      NaN      NaN            NaN         NaN
# 2                  NaN      NaN      NaN            NaN         NaN
# 3                  NaN      NaN      NaN            NaN         NaN
# 4                  NaN      NaN      NaN            NaN         NaN
# ...                ...      ...      ...            ...         ...
# 121500             NaN      NaN      NaN  Notifications         NaN
# 121501             NaN      NaN      NaN  Notifications         NaN
# 121502             NaN      NaN      NaN  Notifications         NaN
# 121503             NaN      NaN      NaN  Notifications         NaN
# 121504             NaN      NaN      NaN  Notifications         NaN
#
#        Impressions click-through rate (%)
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 121500                                NaN
# 121501                                NaN
# 121502                                NaN
# 121503                                NaN
# 121504                                NaN
#
# [121505 rows x 26 columns]

# %%
all_merged_data
# Out:
#               Date                                 Cities    City name  \
# 0       2020-06-28  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 1       2020-06-29  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 2       2020-06-30  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 3       2020-07-01  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# 4       2020-07-02  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa
# ...            ...                                    ...          ...
# 121500  2023-12-24                                    NaN          NaN
# 121501  2023-12-25                                    NaN          NaN
# 121502  2023-12-26                                    NaN          NaN
# 121503  2023-12-27                                    NaN          NaN
# 121504  2023-12-28                                    NaN          NaN
#
#         Views_x Geography Geography.1  Watch time (hours)  \
# 0           0.0       NaN         NaN                 NaN
# 1           0.0       NaN         NaN                 NaN
# 2           0.0       NaN         NaN                 NaN
# 3           0.0       NaN         NaN                 NaN
# 4           0.0       NaN         NaN                 NaN
# ...         ...       ...         ...                 ...
# 121500      1.0       NaN         NaN                 NaN
# 121501      2.0       NaN         NaN                 NaN
# 121502      4.0       NaN         NaN                 NaN
# 121503      0.0       NaN         NaN                 NaN
# 121504      2.0       NaN         NaN                 NaN
#
#        Average view duration  Views_y Subscription source  ...  \
# 0                        NaN      1.0                 NaN  ...
# 1                        NaN     72.0                 NaN  ...
# 2                        NaN     76.0                 NaN  ...
# 3                        NaN     70.0                 NaN  ...
# 4                        NaN     57.0                 NaN  ...
# ...                      ...      ...                 ...  ...
# 121500                   NaN     36.0                 NaN  ...
# 121501                   NaN     24.0                 NaN  ...
# 121502                   NaN     57.0                 NaN  ...
# 121503                   NaN      8.0                 NaN  ...
# 121504                   NaN     25.0                 NaN  ...
#
#         Subtitles and CC  Subscription status  Content type  Device type  \
# 0                    NaN                  NaN           NaN          NaN
# 1                    NaN                  NaN           NaN          NaN
# 2                    NaN                  NaN           NaN          NaN
# 3                    NaN                  NaN           NaN          NaN
# 4                    NaN                  NaN           NaN          NaN
# ...                  ...                  ...           ...          ...
# 121500               NaN                  NaN           NaN          NaN
# 121501               NaN                  NaN           NaN          NaN
# 121502               NaN                  NaN           NaN          NaN
# 121503               NaN                  NaN           NaN          NaN
# 121504               NaN                  NaN           NaN          NaN
#
#        Sharing service Shares_x Shares_y Traffic source Impressions  \
# 0                  NaN      NaN      NaN            NaN         NaN
# 1                  NaN      NaN      NaN            NaN         NaN
# 2                  NaN      NaN      NaN            NaN         NaN
# 3                  NaN      NaN      NaN            NaN         NaN
# 4                  NaN      NaN      NaN            NaN         NaN
# ...                ...      ...      ...            ...         ...
# 121500             NaN      NaN      NaN  Notifications         NaN
# 121501             NaN      NaN      NaN  Notifications         NaN
# 121502             NaN      NaN      NaN  Notifications         NaN
# 121503             NaN      NaN      NaN  Notifications         NaN
# 121504             NaN      NaN      NaN  Notifications         NaN
#
#        Impressions click-through rate (%)
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 121500                                NaN
# 121501                                NaN
# 121502                                NaN
# 121503                                NaN
# 121504                                NaN
#
# [121505 rows x 26 columns]

# %% [markdown]
# # Reflexion on our merge data

# %%
all_merged_data.isnull().sum()
# Out:
# Date                                       0
# Cities                                115110
# City name                             115110
# Views_x                                21743
# Geography                              85690
# Geography.1                           121502
# Watch time (hours)                    118930
# Average view duration                 121488
# Views_y                                21743
# Subscription source                   111273
# Subscribers_x                         111273
# Subscribers gained                    121503
# Subscribers lost                      121503
# Subscribers_y                         111273
# Operating system                      101041
# New and returning viewers             117668
# Subtitles and CC                      112552
# Subscription status                   118947
# Content type                          118947
# Device type                           116389
# Sharing service                       109994
# Shares_x                              109994
# Shares_y                              109994
# Traffic source                        109994
# Impressions                           121505
# Impressions click-through rate (%)    121505
# dtype: int64

# %%
def missing_values_percentage(df):
    # Count the total number of missing values for each column
    total_missing = df.isnull().sum()

    # Calculate the total number of cells in the DataFrame
    total_cells = df.size

    # Calculate the percentage of missing values for each column
    missing_percentage = (total_missing / total_cells) * 100

    # Filter columns with non-zero missing percentage and sort in descending order
    missing_percentage = missing_percentage[missing_percentage > 0].sort_values(ascending=False)

    return missing_percentage

# %%
missing_values_percentage(all_merged_data)
# Out:
# Impressions click-through rate (%)    3.846154
# Impressions                           3.846154
# Subscribers gained                    3.846091
# Subscribers lost                      3.846091
# Geography.1                           3.846059
# Average view duration                 3.845616
# Content type                          3.765182
# Subscription status                   3.765182
# Watch time (hours)                    3.764644
# New and returning viewers             3.724696
# Device type                           3.684211
# City name                             3.643725
# Cities                                3.643725
# Subtitles and CC                      3.562753
# Subscribers_x                         3.522267
# Subscription source                   3.522267
# Subscribers_y                         3.522267
# Sharing service                       3.481781
# Shares_x                              3.481781
# Shares_y                              3.481781
# Traffic source                        3.481781
# Operating system                      3.198381
# Geography                             2.712456
# Views_y                               0.688259
# Views_x                               0.688259
# dtype: float64
